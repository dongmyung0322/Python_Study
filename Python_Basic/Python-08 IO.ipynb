# %%
#IO (input,output)

print(1)
# Out:
# 1

# %%
import sys
print("welcome to","python world", sep="~", end="!" , file=sys.stderr)
# Out:
# welcome to~python world!

# %%
f=open("text.txt","w")
print("welcome to python", file=f)
f.close()

# %%
f=open("text.txt","r")
print(f.read())
print(f.read()) # read: 전부 읽으라는 명령
f.close()
# Out:
# welcome to python

# %%
f=open("text.txt","r")
print(f.readline()) #readline: 한줄씩 읽으라는 명령
f.close()
# Out:
# welcome to python
